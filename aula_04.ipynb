# %% [markdown]
# <a href="https://colab.research.google.com/github/larialbu/curso_machine_learning_senac/blob/main/aula_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Estrutura de repetição

# %% [markdown]
# ##For

# %%
for elemento in [1,2,3,4,5,6]:
  print('Estamos no elemento', elemento)
# Out:
# Estamos no elemento 1
# Estamos no elemento 2
# Estamos no elemento 3
# Estamos no elemento 4
# Estamos no elemento 5
# Estamos no elemento 6

# %%
for elemento in 'STRING':
  print('Estamos no elemento', elemento)
# Out:
# Estamos no elemento S
# Estamos no elemento T
# Estamos no elemento R
# Estamos no elemento I
# Estamos no elemento N
# Estamos no elemento G

# %%
for elemento in range(len('STRING')):
  print('estamos no elemento', elemento)
# Out:
# estamos no elemento 0
# estamos no elemento 1
# estamos no elemento 2
# estamos no elemento 3
# estamos no elemento 4
# estamos no elemento 5

# %% [markdown]
# ##While

# %%
while elemento <= len([1,2,3,4,5,6]):
  print('Estamos no elemento', elemento)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# Estamos no elemento 5
# ...

# %%
elemento = 0

# %%
while elemento <= len([1,2,3,4,5,6]):
  print('Estamos no elemento', elemento)
  elemento += 1
# Out:
# Estamos no elemento 0
# Estamos no elemento 1
# Estamos no elemento 2
# Estamos no elemento 3
# Estamos no elemento 4
# Estamos no elemento 5
# Estamos no elemento 6

# %%
s = 'STRING'
indice = 0

while indice in range(len(s)):
  print('Estamos no element', s[indice])
  indice += 1
# Out:
# Estamos no element S
# Estamos no element T
# Estamos no element R
# Estamos no element I
# Estamos no element N
# Estamos no element G

# %% [markdown]
# ##Enumerante

# %%
palavra = 'tranquilo'
for indice, letra in enumerate(palavra):
  print(indice, letra)
# Out:
# 0 t
# 1 r
# 2 a
# 3 n
# 4 q
# 5 u
# 6 i
# 7 l
# 8 o
